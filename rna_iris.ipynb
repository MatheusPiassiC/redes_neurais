# %% [markdown]
# <a href="https://colab.research.google.com/github/MatheusPiassiC/redes_neurais/blob/main/rna_iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RNA para o dataset *Iris*
# Este notebook consiste na implementação de uma **Rede Neural Artificial** para a o dataset *Iris*, usando a biblioteca *Sklearn* e seu *MLPClassifier*.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##Tratamento dos dados
# A primeira etapa é carregar o dataset para o programa, e após conferir que os dados estão na disposição esperada, devemos separar os conjuntos de treino e teste, e então podemos escala-los.

# %%
dataset = load_iris()


print("número de linhas: " + str(dataset.data.shape[0]))
print("número de colunas: " + str(dataset.data.shape[1]))

print("labels: " + str(dataset.target_names))
# Out:
# número de linhas: 150
# número de colunas: 4
# labels: ['setosa' 'versicolor' 'virginica']

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.data, dataset.target, test_size=0.2, random_state=13)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
from sklearn.preprocessing import MinMaxScaler

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform it
X_train = scaler.fit_transform(X_train)

# Transform the test data using the scaler fitted on the training data
X_test = scaler.transform(X_test)

print("Dados de treino normalizados (primeiras 5 linhas):")
print(X_train[:5])

print("\nDados de teste normalizados (primeiras 5 linhas):")
print(X_test[:5])
# Out:
# Dados de treino normalizados (primeiras 5 linhas):
# [[0.58333333 0.52380952 0.78947368 0.70833333]
#  [0.25       1.         0.0877193  0.        ]
#  [0.30555556 0.66666667 0.0877193  0.125     ]
#  [0.72222222 0.52380952 0.71929825 0.91666667]
#  [0.55555556 0.23809524 0.70175439 0.75      ]]
#
# Dados de teste normalizados (primeiras 5 linhas):
# [[0.38888889 0.38095238 0.61403509 0.5       ]
#  [0.36111111 0.42857143 0.45614035 0.5       ]
#  [0.22222222 0.80952381 0.0877193  0.125     ]
#  [0.41666667 0.33333333 0.71929825 0.75      ]
#  [0.69444444 0.47619048 0.78947368 0.83333333]]

# %% [markdown]
# ## Definição e treino da rede neural artificial
# Em seguida, usamos a classe *MLPClassifier* (uma versão alto nível de um multilayer perceptron) para criar o nosso modelo, e em seguida o treinamos. Foram feitos diversos testes, principalmente variando o número de camadas e a quantidade de neurônios nelas, para gerar o modelo mais enxuto possível, mas com uma acurácia aceitável.

# %%
rna = MLPClassifier(solver='adam', hidden_layer_sizes=(24, 24, 24), random_state=13, max_iter=200, verbose=True)
rna.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 1.30090628
# Iteration 2, loss = 1.28916384
# Iteration 3, loss = 1.27767566
# Iteration 4, loss = 1.26647722
# Iteration 5, loss = 1.25560217
# Iteration 6, loss = 1.24502468
# Iteration 7, loss = 1.23476152
# Iteration 8, loss = 1.22487798
# Iteration 9, loss = 1.21537588
# Iteration 10, loss = 1.20636873
# Iteration 11, loss = 1.19804305
# Iteration 12, loss = 1.19017694
# Iteration 13, loss = 1.18262718
# Iteration 14, loss = 1.17544738
# Iteration 15, loss = 1.16857567
# Iteration 16, loss = 1.16199157
# Iteration 17, loss = 1.15555406
# Iteration 18, loss = 1.14926690
# Iteration 19, loss = 1.14310359
# Iteration 20, loss = 1.13707575
# Iteration 21, loss = 1.13117490
# Iteration 22, loss = 1.12538889
# Iteration 23, loss = 1.11975328
# Iteration 24, loss = 1.11422327
# Iteration 25, loss = 1.10882057
# Iteration 26, loss = 1.10355658
# Iteration 27, loss = 1.09840086
# Iteration 28, loss = 1.09336917
# Iteration 29, loss = 1.08845455
# Iteration 30, loss = 1.08363134
# Iteration 31, loss = 1.07892956
# Iteration 32, loss = 1.07434739
# Iteration 33, loss = 1.06986222
# Iteration 34, loss = 1.06554881
# Iteration 35, loss = 1.06148337
# Iteration 36, loss = 1.05758022
# Iteration 37, loss = 1.05373402
# Iteration 38, loss = 1.04980981
# Iteration 39, loss = 1.04577451
# Iteration 40, loss = 1.04161627
# Iteration 41, loss = 1.03735574
# Iteration 42, loss = 1.03300153
# Iteration 43, loss = 1.02853271
# Iteration 44, loss = 1.02394427
# Iteration 45, loss = 1.01927876
# Iteration 46, loss = 1.01453341
# Iteration 47, loss = 1.00974254
# Iteration 48, loss = 1.00493698
# Iteration 49, loss = 1.00010194
# Iteration 50, loss = 0.99522298
# Iteration 51, loss = 0.99025296
# Iteration 52, loss = 0.98514824
# Iteration 53, loss = 0.97991077
# Iteration 54, loss = 0.97452842
# Iteration 55, loss = 0.96901282
# Iteration 56, loss = 0.96333688
# Iteration 57, loss = 0.95752546
# Iteration 58, loss = 0.95160115
# Iteration 59, loss = 0.94562403
# Iteration 60, loss = 0.93961611
# Iteration 61, loss = 0.93351505
# Iteration 62, loss = 0.92735275
# Iteration 63, loss = 0.92115104
# Iteration 64, loss = 0.91487473
# Iteration 65, loss = 0.90860122
# Iteration 66, loss = 0.90232927
# Iteration 67, loss = 0.89599956
# Iteration 68, loss = 0.88960334
# Iteration 69, loss = 0.88315616
# Iteration 70, loss = 0.87661046
# Iteration 71, loss = 0.86996360
# Iteration 72, loss = 0.86320477
# Iteration 73, loss = 0.85627645
# Iteration 74, loss = 0.84923175
# Iteration 75, loss = 0.84208525
# Iteration 76, loss = 0.83490632
# Iteration 77, loss = 0.82765184
# Iteration 78, loss = 0.82030633
# Iteration 79, loss = 0.81290536
# Iteration 80, loss = 0.80542860
# Iteration 81, loss = 0.79787957
# Iteration 82, loss = 0.79024735
# Iteration 83, loss = 0.78255672
# Iteration 84, loss = 0.77481653
# Iteration 85, loss = 0.76706007
# Iteration 86, loss = 0.75929233
# Iteration 87, loss = 0.75150119
# Iteration 88, loss = 0.74367317
# Iteration 89, loss = 0.73583907
# Iteration 90, loss = 0.72803338
# Iteration 91, loss = 0.72024449
# Iteration 92, loss = 0.71250104
# Iteration 93, loss = 0.70483624
# Iteration 94, loss = 0.69724649
# Iteration 95, loss = 0.68973654
# Iteration 96, loss = 0.68233135
# Iteration 97, loss = 0.67501207
# Iteration 98, loss = 0.66777929
# Iteration 99, loss = 0.66063335
# Iteration 100, loss = 0.65361692
# Iteration 101, loss = 0.64672756
# Iteration 102, loss = 0.63993973
# Iteration 103, loss = 0.63325472
# Iteration 104, loss = 0.62670208
# Iteration 105, loss = 0.62026324
# Iteration 106, loss = 0.61395329
# Iteration 107, loss = 0.60775878
# Iteration 108, loss = 0.60167078
# Iteration 109, loss = 0.59571978
# Iteration 110, loss = 0.58988407
# Iteration 111, loss = 0.58415090
# Iteration 112, loss = 0.57853508
# Iteration 113, loss = 0.57305758
# Iteration 114, loss = 0.56768107
# Iteration 115, loss = 0.56239865
# Iteration 116, loss = 0.55727006
# Iteration 117, loss = 0.55231241
# Iteration 118, loss = 0.54748615
# Iteration 119, loss = 0.54278678
# Iteration 120, loss = 0.53822985
# Iteration 121, loss = 0.53379880
# Iteration 122, loss = 0.52948166
# Iteration 123, loss = 0.52527152
# Iteration 124, loss = 0.52117832
# Iteration 125, loss = 0.51721519
# Iteration 126, loss = 0.51335088
# Iteration 127, loss = 0.50958193
# Iteration 128, loss = 0.50591052
# Iteration 129, loss = 0.50232032
# Iteration 130, loss = 0.49882466
# Iteration 131, loss = 0.49541044
# Iteration 132, loss = 0.49207399
# Iteration 133, loss = 0.48882964
# Iteration 134, loss = 0.48565908
# Iteration 135, loss = 0.48255261
# Iteration 136, loss = 0.47950488
# Iteration 137, loss = 0.47651595
# Iteration 138, loss = 0.47358159
# Iteration 139, loss = 0.47069880
# Iteration 140, loss = 0.46786747
# Iteration 141, loss = 0.46507862
# Iteration 142, loss = 0.46233301
# Iteration 143, loss = 0.45962491
# Iteration 144, loss = 0.45695329
# Iteration 145, loss = 0.45431303
# Iteration 146, loss = 0.45170621
# Iteration 147, loss = 0.44911784
# Iteration 148, loss = 0.44655288
# Iteration 149, loss = 0.44402391
# Iteration 150, loss = 0.44151853
# Iteration 151, loss = 0.43902641
# Iteration 152, loss = 0.43657135
# Iteration 153, loss = 0.43412952
# Iteration 154, loss = 0.43172303
# Iteration 155, loss = 0.42935022
# Iteration 156, loss = 0.42699902
# Iteration 157, loss = 0.42466411
# Iteration 158, loss = 0.42235966
# Iteration 159, loss = 0.42006656
# Iteration 160, loss = 0.41776832
# Iteration 161, loss = 0.41546786
# Iteration 162, loss = 0.41317551
# Iteration 163, loss = 0.41089170
# Iteration 164, loss = 0.40862340
# Iteration 165, loss = 0.40635789
# Iteration 166, loss = 0.40408768
# Iteration 167, loss = 0.40180577
# Iteration 168, loss = 0.39951118
# Iteration 169, loss = 0.39720834
# Iteration 170, loss = 0.39488293
# Iteration 171, loss = 0.39252909
# Iteration 172, loss = 0.39014839
# Iteration 173, loss = 0.38770963
# Iteration 174, loss = 0.38521304
# Iteration 175, loss = 0.38263202
# Iteration 176, loss = 0.37999664
# Iteration 177, loss = 0.37733046
# Iteration 178, loss = 0.37463379
# Iteration 179, loss = 0.37191954
# Iteration 180, loss = 0.36915571
# Iteration 181, loss = 0.36638722
# Iteration 182, loss = 0.36358547
# Iteration 183, loss = 0.36076085
# Iteration 184, loss = 0.35795582
# Iteration 185, loss = 0.35512256
# Iteration 186, loss = 0.35225464
# Iteration 187, loss = 0.34936631
# Iteration 188, loss = 0.34648578
# Iteration 189, loss = 0.34359717
# Iteration 190, loss = 0.34067094
# Iteration 191, loss = 0.33770427
# Iteration 192, loss = 0.33469171
# Iteration 193, loss = 0.33164240
# Iteration 194, loss = 0.32855504
# Iteration 195, loss = 0.32542814
# Iteration 196, loss = 0.32225406
# Iteration 197, loss = 0.31904239
# Iteration 198, loss = 0.31579905
# Iteration 199, loss = 0.31254906
# Iteration 200, loss = 0.30923927
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(24, 24, 24), random_state=13, verbose=True)

# %%
print(rna.predict(X_test[:10]))
print(y_test[:10])

rna.score(X_test, y_test)
# Out:
# [1 1 0 2 2 0 2 2 0 1]
# [1 1 0 2 2 0 2 2 0 1]
# 1.0

# %% [markdown]
# ## Resultados
# Por fim, mostramos as métricas de avaliação do modelo para o conjunto de teste (matriz de confusão, acurácia, precisão, recall).

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

y_pred = rna.predict(X_test)

cm = confusion_matrix(y_test, y_pred)
print("Matriz de Confusão:")
print(cm)

accuracy = accuracy_score(y_test, y_pred)
print(f"\nAcurácia: {accuracy:.4f}")

precision = precision_score(y_test, y_pred, average='macro')
print(f"Precisão (macro average, média entre as classes): {precision:.4f}")

recall = recall_score(y_test, y_pred, average='macro')
print(f"Recall (macro average, média entre as classes): {recall:.4f}")
# Out:
# Matriz de Confusão:
# [[14  0  0]
#  [ 0 12  0]
#  [ 0  0 19]]
#
# Acurácia: 1.0000
# Precisão (macro average, média entre as classes): 1.0000
# Recall (macro average, média entre as classes): 1.0000
